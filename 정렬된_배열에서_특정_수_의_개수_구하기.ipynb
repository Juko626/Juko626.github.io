# %% [markdown]
# <a href="https://colab.research.google.com/github/Juko626/Juko626.github.io/blob/master/%EC%A0%95%EB%A0%AC%EB%90%9C_%EB%B0%B0%EC%97%B4%EC%97%90%EC%84%9C_%ED%8A%B9%EC%A0%95_%EC%88%98_%EC%9D%98_%EA%B0%9C%EC%88%98_%EA%B5%AC%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n,x=map(int,input().split())
array=list(map(int,input().split()))
# Out:
# 7 2
# 1 1 2 2 2 2 3

# %%
from bisect import bisect_left, bisect_right

def count_by_range(array,left_value, right_value):
  right_index=bisect_right(array,right_value)
  left_index=bisect_left(array,left_value)
  return right_index-left_index

count=count_by_range(array,x,x)

if count==0:
  print(-1)
else:
  print(count)
# Out:
# 4
